# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Datos\archive\Car details v3.csv')
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %% [markdown]
# First of all we will look if there are any missing values

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# ...

# %%
df = df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          208
# engine           208
# max_power        205
# torque           209
# seats            208
# dtype: int64

# %%
df[df['engine'].isna()]
# Out:
#                                       name  year  selling_price  km_driven  \
# 13                    Maruti Swift 1.3 VXi  2007         200000      80000
# 31                      Fiat Palio 1.2 ELX  2003          70000      50000
# 78                         Tata Indica DLS  2003          50000      70000
# 87             Maruti Swift VDI BSIV W ABS  2015         475000      78000
# 119                  Maruti Swift VDI BSIV  2010         300000     120000
# ...                                    ...   ...            ...        ...
# 7740                Hyundai Santro Xing XG  2004          70000      70000
# 7996             Hyundai Santro LS zipPlus  2000         140000      50000
# 8009  Hyundai Santro Xing XS eRLX Euro III  2006         145000      80000
# 8068             Ford Figo Aspire Facelift  2017         580000     165000
# 8103                  Maruti Swift 1.3 VXi  2006         130000     100000
#
# ...

# %%
df['mileage'] = df['mileage'].str.strip('/kmplg')
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\2539827937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mileage'] = df['mileage'].str.strip('/kmplg')

# %%
df['mileage'] = pd.to_numeric(df['mileage'])
df
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\3246735242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mileage'] = pd.to_numeric(df['mileage'])
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# ...

# %%
avg_mil = df['mileage'].mean()

# %%
df['mileage'].fillna(value=avg_mil, inplace=True)
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\1526576980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mileage'].fillna(value=avg_mil, inplace=True)

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage            0
# engine           208
# max_power        205
# torque           209
# seats            208
# dtype: int64

# %%
df['engine'] = df['engine'].str.strip('C')
df['engine'] = pd.to_numeric(df['engine'])
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\1865559604.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine'] = df['engine'].str.strip('C')
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\1865559604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine'] = pd.to_numeric(df['engine'])

# %%
mean_eng = df['engine'].mean()

# %%
df['engine'].fillna(value=mean_eng, inplace=True)
df
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\2037026773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine'].fillna(value=mean_eng, inplace=True)
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# ...

# %%
df['max_power'] = df['max_power'].str.strip('bhp ')
df['max_power'] = pd.to_numeric(df['max_power'])
mean_pow = df['max_power'].mean()
df['max_power'].fillna(value=mean_pow, inplace=True)
df
# Out:
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\534544678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_power'] = df['max_power'].str.strip('bhp ')
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\534544678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_power'] = pd.to_numeric(df['max_power'])
# C:\Users\fabia\AppData\Local\Temp\ipykernel_6180\534544678.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage            0
# engine             0
# max_power          0
# torque           209
# seats            208
# dtype: int64

# %%
df.drop(['fuel', 'seller_type','torque', 'seats'], axis=1)
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#      transmission                 owner  mileage  engine  max_power
# ...

# %%
df = df.drop(['fuel', 'seller_type','torque', 'seats'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6926 entries, 0 to 8125
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6926 non-null   object
#  1   year           6926 non-null   int64
#  2   selling_price  6926 non-null   int64
#  3   km_driven      6926 non-null   int64
#  4   transmission   6926 non-null   object
#  5   owner          6926 non-null   object
#  6   mileage        6926 non-null   float64
#  7   engine         6926 non-null   float64
#  8   max_power      6926 non-null   float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 541.1+ KB

# %%
owners = df['owner'].unique()
owners.sort()
owners
# Out:
# array(['First Owner', 'Fourth & Above Owner', 'Second Owner',
#        'Test Drive Car', 'Third Owner'], dtype=object)

# %%
df[df['owner'] == 'Test Drive Car']
# Out:
#                                         name  year  selling_price  km_driven  \
# 4383  Volkswagen Vento 1.5 TDI Highline BSIV  2019        1350000       5400
# 4950                  Audi A6 35 TFSI Matrix  2019        6223000       7800
# 4951                  Audi A6 35 TFSI Matrix  2019        5923000      11500
# 4952                  Audi A6 35 TFSI Matrix  2019        6523000      23600
# 6220                          Honda Civic ZX  2019        2000000      24857
#
#      transmission           owner  mileage  engine  max_power
# 4383       Manual  Test Drive Car    22.27  1498.0     108.60
# 4950    Automatic  Test Drive Car    15.26  1798.0     187.74
# 4951    Automatic  Test Drive Car    15.26  1798.0     187.74
# 4952    Automatic  Test Drive Car    15.26  1798.0     187.74
# 6220    Automatic  Test Drive Car    16.50  1799.0     139.46

# %%
df['owner'] = df['owner'].str.replace('Test Drive Car', 'First Owner')

# %%
df[df['name'] == 'Honda Civic ZX']
# Out:
#                 name  year  selling_price  km_driven transmission  \
# 6220  Honda Civic ZX  2019        2000000      24857    Automatic
#
#             owner  mileage  engine  max_power
# 6220  First Owner     16.5  1799.0     139.46

# %%
word_to_number = {'First Owner': 1, 'Second Owner': 2, 'Third Owner':3, 'Fourth & Above Owner':4}
df.replace({'owner': word_to_number}, inplace=True)
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#      transmission  owner  mileage  engine  max_power
# ...

# %%
transmission = df['transmission'].unique()
transmission.sort()
transmission
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
df[df['owner'] == 'Test Drive Ca']
# Out:
# Empty DataFrame
# Columns: [name, year, selling_price, km_driven, transmission, owner, mileage, engine, max_power]
# Index: []

# %%
df[df['name'] == 'Honda Civic ZX']
# Out:
#                 name  year  selling_price  km_driven transmission  owner  \
# 6220  Honda Civic ZX  2019        2000000      24857    Automatic      1
#
#       mileage  engine  max_power
# 6220     16.5  1799.0     139.46

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#      transmission  owner  mileage  engine  max_power
# ...

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'transmission', 'owner',
#        'mileage', 'engine', 'max_power'],
#       dtype='object')

# %%
df_variables = [ 'year', 'selling_price', 'km_driven', 'owner',
       'mileage', 'engine', 'max_power']
R = df[df_variables]
R
# Out:
#       year  selling_price  km_driven  owner  mileage  engine  max_power
# 0     2014         450000     145500      1    23.40  1248.0      74.00
# 1     2014         370000     120000      2    21.14  1498.0     103.52
# 2     2006         158000     140000      3    17.70  1497.0      78.00
# 3     2010         225000     127000      1    23.00  1396.0      90.00
# 4     2007         130000     120000      1    16.10  1298.0      88.20
# ...    ...            ...        ...    ...      ...     ...        ...
# 8121  2013         260000      50000      2    18.90   998.0      67.10
# 8122  2014         475000      80000      2    22.54  1396.0      88.73
# 8123  2013         320000     110000      1    18.50  1197.0      82.85
# 8124  2007         135000     119000      4    16.80  1493.0     110.00
# 8125  2009         382000     120000      1    19.30  1248.0      73.90
#
# [6926 rows x 7 columns]

# %%
R.corr()
# Out:
#                    year  selling_price  km_driven     owner   mileage  \
# year           1.000000       0.433076  -0.377003 -0.494393  0.345414
# selling_price  0.433076       1.000000  -0.165620 -0.247448 -0.107479
# km_driven     -0.377003      -0.165620   1.000000  0.259879 -0.194653
# owner         -0.494393      -0.247448   0.259879  1.000000 -0.182254
# mileage        0.345414      -0.107479  -0.194653 -0.182254  1.000000
# engine        -0.017967       0.439321   0.250966  0.030431 -0.578483
# max_power      0.150300       0.686013   0.041387 -0.059268 -0.377838
#
#                  engine  max_power
# year          -0.017967   0.150300
# selling_price  0.439321   0.686013
# km_driven      0.250966   0.041387
# owner          0.030431  -0.059268
# mileage       -0.578483  -0.377838
# engine         1.000000   0.682257
# max_power      0.682257   1.000000

# %%
f,ax = plt.subplots(figsize=(5, 4))
sns.heatmap(R.corr())
plt.show()

# %%
R.corr()['selling_price'].sort_values()
# Out:
# owner           -0.247448
# km_driven       -0.165620
# mileage         -0.107479
# year             0.433076
# engine           0.439321
# max_power        0.686013
# selling_price    1.000000
# Name: selling_price, dtype: float64

# %%
sns.lmplot(data=df, x='max_power', y='selling_price', order=2, ci=None)

# %%
df[df['max_power']>300]
# Out:
#                               name  year  selling_price  km_driven  \
# 170  Volvo XC90 T8 Excellence BSIV  2017       10000000      30000
#
#     transmission  owner  mileage  engine  max_power
# 170    Automatic      1     42.0  1969.0      400.0

# %%
df.drop(df[df['max_power']>=300].index, inplace=True)

# %%
sns.lmplot(data=df, x='max_power', y='selling_price', order=2, ci=None)

# %%
sns.lmplot(data=df, x='engine', y='selling_price')

# %%
sns.lmplot(data=df, x='mileage', y='selling_price', order=2, ci=None)

# %%
sns.lmplot(data=df, x='year', y='selling_price', order=2, ci=None)

# %%
df.drop(df[df['year'] <= 1990].index, inplace=True)

# %%
sns.lmplot(data=df, x='year', y='selling_price', order=2, ci=None)

# %%
df_variables = [ 'year', 'selling_price', 'km_driven', 'owner',
       'mileage', 'engine', 'max_power']
R = df[df_variables]
R
# Out:
#       year  selling_price  km_driven  owner  mileage  engine  max_power
# 0     2014         450000     145500      1    23.40  1248.0      74.00
# 1     2014         370000     120000      2    21.14  1498.0     103.52
# 2     2006         158000     140000      3    17.70  1497.0      78.00
# 3     2010         225000     127000      1    23.00  1396.0      90.00
# 4     2007         130000     120000      1    16.10  1298.0      88.20
# ...    ...            ...        ...    ...      ...     ...        ...
# 8121  2013         260000      50000      2    18.90   998.0      67.10
# 8122  2014         475000      80000      2    22.54  1396.0      88.73
# 8123  2013         320000     110000      1    18.50  1197.0      82.85
# 8124  2007         135000     119000      4    16.80  1493.0     110.00
# 8125  2009         382000     120000      1    19.30  1248.0      73.90
#
# [6924 rows x 7 columns]

# %%
R.corr()
# Out:
#                    year  selling_price  km_driven     owner   mileage  \
# year           1.000000       0.442860  -0.379687 -0.494325  0.346912
# selling_price  0.442860       1.000000  -0.167806 -0.251715 -0.125712
# km_driven     -0.379687      -0.167806   1.000000  0.260239 -0.194512
# owner         -0.494325      -0.251715   0.260239  1.000000 -0.182170
# mileage        0.346912      -0.125712  -0.194512 -0.182170  1.000000
# engine        -0.018183       0.447333   0.251141  0.030554 -0.580779
# max_power      0.150735       0.681097   0.042788 -0.058716 -0.389686
#
#                  engine  max_power
# year          -0.018183   0.150735
# selling_price  0.447333   0.681097
# km_driven      0.251141   0.042788
# owner          0.030554  -0.058716
# mileage       -0.580779  -0.389686
# engine         1.000000   0.685669
# max_power      0.685669   1.000000

# %%
f,ax = plt.subplots(figsize=(5, 4))
sns.heatmap(R.corr())
plt.show()

# %%
R.corr()['selling_price'].sort_values()
# Out:
# owner           -0.251715
# km_driven       -0.167806
# mileage         -0.125712
# year             0.442860
# engine           0.447333
# max_power        0.681097
# selling_price    1.000000
# Name: selling_price, dtype: float64

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        owner      mileage  \
# count  6924.000000   6.924000e+03  6.924000e+03  6924.000000  6924.000000
# mean   2013.424177   5.159325e+05  7.401127e+04     1.512854    19.462055
# std       4.062227   5.071866e+05  5.835906e+04     0.742224     3.979244
# min    1991.000000   2.999900e+04  1.000000e+00     1.000000     0.000000
# 25%    2011.000000   2.500000e+05  4.000000e+04     1.000000    16.950000
# 50%    2014.000000   4.000000e+05  7.000000e+04     1.000000    19.465310
# 75%    2017.000000   6.325000e+05  1.000000e+05     2.000000    22.320000
# max    2020.000000   7.200000e+06  2.360457e+06     4.000000    33.440000
#
#             engine    max_power
# count  6924.000000  6924.000000
# mean   1430.813620    87.681819
# std     486.052636    31.074156
# min     624.000000     0.000000
# 25%    1197.000000    68.000000
# 50%    1248.000000    81.860000
# 75%    1498.000000    99.000000
# max    3604.000000   282.000000

# %%
df[df['km_driven'] >= 1e6]
# Out:
#                         name  year  selling_price  km_driven transmission  \
# 1810  Mahindra XUV500 W6 2WD  2012         500000    1500000       Manual
# 3486    Hyundai i20 Asta 1.2  2007         550000    2360457       Manual
#
#       owner  mileage  engine  max_power
# 1810      1     15.1  2179.0     140.00
# 3486      2     18.6  1197.0      81.83

# %%
df.drop(df[df['km_driven'] >= 1e6].index, inplace = True)

# %%
df
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#      transmission  owner  mileage  engine  max_power
# ...

# %%
sns.lmplot(data=df, x='km_driven', y='selling_price', order=2, ci=None)

# %%
sns.displot(data=df, x='owner', y='selling_price')

# %% [markdown]
# # Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
X_power = df[['max_power']]
y_power = df['selling_price']

# %%
linear_reg = LinearRegression().fit(X_power, y_power)
linear_reg
# Out:
# LinearRegression()

# %%
print('Coefficient',linear_reg.coef_)
print('Intercept',linear_reg.intercept_)
# Out:
# Coefficient [11121.51026562]
# Intercept -459149.69789313467

# %%
linear_reg.predict(df[['max_power']])
# Out:
# array([363842.06176242, 692149.04480339, 408328.10282488, ...,
#        462267.42761311, 764216.43132458, 362729.91073586])

# %%
X_min_max = np.array([[df['max_power'].min()], [df['max_power'].max()]])
X_min_max
# Out:
# array([[  0.],
#        [282.]])

# %%
y_predict = linear_reg.predict(X_min_max)
y_predict
# Out:
# C:\Users\fabia\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-459149.69789313, 2677116.19701046])

# %%
sns.lmplot(data=df, x='max_power', y='selling_price', ci=None)
plt.plot(X_min_max, y_predict, "g-")
plt.xlabel('Power')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn import linear_model

# %%
mult_reg = linear_model.LinearRegression()
mult_reg.fit(df[['year', 'km_driven', 'owner',
       'mileage', 'engine', 'max_power']], df['selling_price'])
# Out:
# LinearRegression()

# %%
precio_promedio = df['selling_price'].mean()
precio_promedio
# Out:
# 515929.89295001444

# %%
mult_reg.coef_
# Out:
# array([ 3.36262866e+04, -1.26088073e+00, -2.99038215e+04,  4.77416775e+03,
#         1.18692156e+02,  9.47181350e+03])

# %%
mult_reg.intercept_
# Out:
# -68143381.68687055

# %% [markdown]
# 'year',  'km_driven',  'owner',
#         'mileage',  'engine',  'max_power'

# %%
mult_reg.predict([[2013, 75000, 1, 20, 1450, 90 ]])
# Out:
# C:\Users\fabia\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([541913.46227606])

# %%
mult_reg.predict([[2015, 205841.535, 1, 31, 1395, 150 ]]) 
#Real Price: 12,500
# Out:
# C:\Users\fabia\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1058487.05186987])

# %%
mult_reg.predict([[2013, 50000, 2, 18.90, 998.0, 67.10]])
# Out:
# C:\Users\fabia\anaconda3\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([267726.69095822])

# %% [markdown]
# # Selecting the prediction target

# %%
y = df.selling_price

# %% [markdown]
# # Choosing "features"

# %%
df_features = [ 'year', 'km_driven', 'owner',
       'mileage', 'engine', 'max_power']

# %%
X = df[df_features]

# %%
X.describe()
# Out:
#               year      km_driven        owner     mileage      engine  \
# count  6922.000000    6922.000000  6922.000000  6922.00000  6922.00000
# mean   2013.425311   73474.949148     1.512858    19.46281  1430.73931
# std       4.062044   48552.139340     0.742283     3.97946   486.03153
# min    1991.000000       1.000000     1.000000     0.00000   624.00000
# 25%    2011.000000   40000.000000     1.000000    16.95000  1197.00000
# 50%    2014.000000   70000.000000     1.000000    19.46531  1248.00000
# 75%    2017.000000  100000.000000     2.000000    22.32000  1498.00000
# max    2020.000000  577414.000000     4.000000    33.44000  3604.00000
#
#          max_power
# count  6922.000000
# mean     87.675106
# std      31.072201
# min       0.000000
# 25%      68.000000
# 50%      81.860000
# 75%      99.000000
# max     282.000000

# %%
X.head()
# Out:
#    year  km_driven  owner  mileage  engine  max_power
# 0  2014     145500      1    23.40  1248.0      74.00
# 1  2014     120000      2    21.14  1498.0     103.52
# 2  2006     140000      3    17.70  1497.0      78.00
# 3  2010     127000      1    23.00  1396.0      90.00
# 4  2007     120000      1    16.10  1298.0      88.20
